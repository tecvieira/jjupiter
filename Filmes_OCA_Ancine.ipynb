# %% [markdown]
# # Analise de filmes Brasileiros e Estrangeiros de 2009 a 2019.
# Com base nos dados da Ancine (http://oca.ancine.gov.br)
#
# Analisando os filmes exibidos no Brasil.
#
# Arquivo 2120.xlsx

# %%
import pandas as pd
#importando o pandas
# %matplotlib inline
#configurando o matplot inline para mostrar o gráfico aqui.

# %%
dF = pd.read_excel('2120.xlsx', skiprows=2, skipfooter=20)
#importa o arquivo em excel e (skiprows=2 elimina as 2 linhas que nao desejamos no excel, visto no original)
dF.head()
# Out:
#    Ano de exibição              Título da obra         CPB/ROE    Gênero  \
# 0             2019   120 Batimentos Por Minuto  E1700453800000    Ficção
# 1             2019                     3 Faces  E1800494900000    Ficção
# 2             2019            45 Dias Sem Você  B1800586000000    Ficção
# 3             2019    A 100 Passos De Um Sonho  E1402795100000    Ficção
# 4             2019  A Abelhinha Maya - O Filme  E1800136100000  Animação
#
#   País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 0                        França           Estrangeira              43104
# 1                           Irã           Estrangeira              43559
# 2                        Brasil            Brasileira              43601
# 3                Estados Unidos           Estrangeira              41879
# 4                      Alemanha           Estrangeira              43237
#
#   Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %%
dF.tail(5)
# Out:
#       Ano de exibição       Título da obra         CPB/ROE        Gênero  \
# 7076             2009          Xuxa Gêmeas  B0600616500000        Ficção
# 7077             2009         Zico na Rede  B0901041400000  Documentário
# 7078             2009             À Deriva  B0901015000000        Ficção
# 7079             2009     É Proibido Fumar  B0901108700000        Ficção
# 7080             2009  Última Parada - 174  B0800914800000        Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7076                        Brasil            Brasileira              39066
# 7077                        Brasil            Brasileira              39997
# 7078        Brasil, Estados Unidos            Brasileira              40025
# 7079                        Brasil            Brasileira              40151
# 7080                        Brasil            Brasileira              39745
#
#      Empresa distribuidora Origem da empresa distribuidora  \
# ...
